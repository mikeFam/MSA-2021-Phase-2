# %%
import os, re, sys, json
import pandas as pd
import numpy as np
import platform
from google.colab import drive

def linux_distribution():
    try:
        return platform.linux_distribution()
    except:
        return 'N/A'

print('''Python version: %s
platform: %s
uname: %s
version: %s
''' % (sys.version.split('\n'), platform.platform(), platform.uname(), platform.version()))

drive.mount('/content/drive')

os.chdir('/content/drive/MyDrive/ColabNotebooks/')
print('Current Working Directory ' , os.getcwd())
# Out:
# Python version: ['3.7.12 (default, Sep 10 2021, 00:21:48) ', '[GCC 7.5.0]']
# platform: Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic
# uname: uname_result(system='Linux', node='0392d684fa20', release='5.4.104+', version='#1 SMP Sat Jun 5 09:50:34 PDT 2021', machine='x86_64', processor='x86_64')
# version: #1 SMP Sat Jun 5 09:50:34 PDT 2021
#
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Current Working Directory  /content/drive/MyDrive/ColabNotebooks

# %%
# read model
import joblib
model = joblib.load("linearRegressorModel.joblib")
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator MLPRegressor from version 0.23.2 when using version 0.22.2.post1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(lowercase=True,analyzer="word", stop_words='english',max_features=10, strip_accents='unicode')
vecFlag = False

request = {
    "data": " Immediately after the try block, make an except block with except Exception as e to handle any exceptions that occur where e is the exception object, which can be printed. To catch a specific exception, replace Exception with the name of the specific exception."
}

data = request["data"]
# print(data)

print(len(data.split(" ")))

paragraphArr = np.array([data], dtype='object')

try:
    vectorizer.fit_transform(paragraphArr).toarray()
    paragraphArrVec = vectorizer.transform(paragraphArr).toarray()
    result = model.predict(paragraphArrVec)
except Exception as e:
    print(e)
    result = np.array([2], dtype='float32')
result = np.array2string(result, precision=3)
while '[' in result:
    result = result[result.find('[')+1: result.rfind(']')]
if result[-1] == '.':
    result = result[:-1]
else:
    pass
result
# Out:
# 45
# '-0.182'
